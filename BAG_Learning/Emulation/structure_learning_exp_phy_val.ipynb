# %% [markdown]
# Bayesian Network to model the influence of various cyber features in intrusion detection

# %%
import pandas as pd
import numpy as np
from pgmpy.estimators import ExhaustiveSearch,HillClimbSearch,K2Score, PC,TreeSearch

# %%
use_case ='UC1'
path_dataset = 'C:\\Users\\substationc\\Desktop\\DataFusion\\DataFusionApp\\DataFusionApp\\PythonScripts\\csvs\\'+use_case

master_file = path_dataset+'\\merged_phy_cyb_10os_30poll_encoded.csv'
os_file = path_dataset+'\\DS_merged_phy_cyb_10os_30poll_encoded_uc1.csv'
router_file = path_dataset+'\\router_merged_phy_cyb_10os_30poll_encoded_uc1.csv'

# %%
master_data = pd.read_csv(master_file)
os_data = pd.read_csv(os_file)
router_data = pd.read_csv(router_file)

# %%
master_data['Time'] = master_data['Time'].astype(str)
master_data['Time'] = pd.to_datetime(master_data['Time'], format ='%Y-%m-%d %H:%M:%S.%f')
#master_data['Time'] = pd.to_datetime(master_data['Time']).values.astype(np.int64)// 10**6

os_data['Time'] = os_data['Time'].astype(str)
os_data['Time'] = pd.to_datetime(os_data['Time'], format ='%Y-%m-%d %H:%M:%S.%f')
#os_data['Time'] = pd.to_datetime(os_data['Time']).values.astype(np.int64)// 10**6

router_data['Time'] = router_data['Time'].astype(str)
router_data['Time'] = pd.to_datetime(os_data['Time'], format ='%Y-%m-%d %H:%M:%S.%f')
#router_data['Time'] = pd.to_datetime(router_data['Time']).values.astype(np.int64)// 10**6

# %%
master_data.head(5)
# Out:
#    Unnamed: 0  frame_len  frame_protocols  eth_src  eth_dst  ip_src  ip_dst  \
# 0           0         72                1        1        0       1       2
# 1           1        286                1        0        1       2       1
# 2           2         72                1        1        0       1       2
# 3           3        293                1        0        1       2       1
# 4           4         72                1        1        0       1       2
#
#    ip_len  ip_flags  tcp_srcport  ...  AL_dnp3_al_func  AL_dnp3_al_ctl  \
# 0      12         1            5  ...              129              10
# 1       9         1            1  ...              129               7
# 2      12         1           12  ...              129               9
# 3      10         1            1  ...              129              12
# 4      12         1            3  ...              129               8
#
#    AL_dnp3_obj  DNP3 Object Count  DNP3 Objects  AL_Payload  value1  value2  \
# 0            0                 55             2          44     NaN     NaN
# 1            0                 58             1          48     NaN     NaN
# 2            0                 33             0          94     NaN     NaN
# 3            0                 38             1         126     NaN     NaN
# 4            0                 46             1          17     NaN     NaN
#
#     value3  value4
# 0      NaN     NaN
# 1      NaN -125.49
# 2      NaN -125.49
# 3      NaN -125.49
# 4 -197.574 -125.49
#
# [5 rows x 36 columns]

# %%
# rename the column name of each table to merge 
master_data.columns = ['M'+col_name for col_name in master_data.columns]
os_data.columns = ['O'+col_name for col_name in os_data.columns]
router_data.columns = ['R'+col_name for col_name in router_data.columns]

# %%
# join all the table with a resolution of 10 sec
master_data = master_data.set_index('MTime')
os_data = os_data.set_index('OTime')
router_data = router_data.set_index('RTime')
master_resample = master_data.resample('10S').mean()
os_resample = os_data.resample('10S').mean()
router_resample = router_data.resample('10S').mean()
res = master_resample.join(os_resample)
res = res.join(router_resample)

# %%
res
# Out:
#                      MUnnamed: 0  Mframe_len  Mframe_protocols  Meth_src  \
# MTime
# 2020-10-17 15:51:40          1.5  180.750000          1.000000  0.500000
# 2020-10-17 15:51:50          5.0  116.666667          1.000000  0.666667
# 2020-10-17 15:52:00          8.0  109.000000          0.333333  0.333333
# 2020-10-17 15:52:10         11.5  144.750000          1.000000  0.500000
# 2020-10-17 15:52:20         15.0  117.333333          1.000000  0.666667
# ...                          ...         ...               ...       ...
# 2020-10-17 16:06:10        331.0  172.333333          1.000000  0.444444
# 2020-10-17 16:06:20        336.5  127.000000          1.000000  0.500000
# 2020-10-17 16:06:30          NaN         NaN               NaN       NaN
# 2020-10-17 16:06:40        341.5  103.750000          0.750000  0.500000
# 2020-10-17 16:06:50        346.5  107.000000          1.000000  0.500000
#
#                      Meth_dst   Mip_src   Mip_dst    Mip_len  Mip_flags  \
# MTime
# 2020-10-17 15:51:40  0.500000  1.500000  1.500000  10.750000   1.000000
# 2020-10-17 15:51:50  0.333333  1.333333  1.666667   9.333333   1.000000
# 2020-10-17 15:52:00  0.666667  0.666667  0.333333   2.000000   0.333333
# 2020-10-17 15:52:10  0.500000  1.500000  1.500000   8.500000   1.000000
# 2020-10-17 15:52:20  0.333333  1.333333  1.666667   9.666667   1.000000
# ...                       ...       ...       ...        ...        ...
# 2020-10-17 16:06:10  0.555556  1.555556  1.444444   9.444444   1.000000
# 2020-10-17 16:06:20  0.500000  1.500000  1.500000   7.000000   1.000000
# 2020-10-17 16:06:30       NaN       NaN       NaN        NaN        NaN
# 2020-10-17 16:06:40  0.500000  1.125000  1.125000   7.875000   0.750000
# 2020-10-17 16:06:50  0.500000  1.500000  1.500000   6.500000   1.000000
#
#                      Mtcp_srcport  ...  RAL_dnp3_al_func  RAL_dnp3_al_ctl  \
# MTime                              ...
# 2020-10-17 15:51:40      4.750000  ...             129.0             11.5
# 2020-10-17 15:51:50      4.333333  ...             129.0              4.0
# 2020-10-17 15:52:00      0.333333  ...             129.0              6.0
# 2020-10-17 15:52:10      5.750000  ...             129.0             12.5
# 2020-10-17 15:52:20      3.666667  ...             129.0              5.0
# ...                           ...  ...               ...              ...
# 2020-10-17 16:06:10      4.444444  ...               NaN              NaN
# 2020-10-17 16:06:20      5.500000  ...               NaN              NaN
# 2020-10-17 16:06:30           NaN  ...               NaN              NaN
# 2020-10-17 16:06:40      2.125000  ...               NaN              NaN
# 2020-10-17 16:06:50      3.500000  ...               NaN              NaN
#
#                      RAL_dnp3_obj  RDNP3 Object Count  RDNP3 Objects  \
# MTime
# 2020-10-17 15:51:40      0.000000           47.000000       1.000000
# 2020-10-17 15:51:50      0.333333           37.333333      43.000000
# 2020-10-17 15:52:00      1.000000           28.000000     260.333333
# 2020-10-17 15:52:10      0.000000           47.000000       1.000000
# 2020-10-17 15:52:20      0.333333           37.333333      43.000000
# ...                           ...                 ...            ...
# 2020-10-17 16:06:10           NaN                 NaN            NaN
# 2020-10-17 16:06:20           NaN                 NaN            NaN
# 2020-10-17 16:06:30           NaN                 NaN            NaN
# 2020-10-17 16:06:40           NaN                 NaN            NaN
# 2020-10-17 16:06:50           NaN                 NaN            NaN
#
#                      RAL_Payload  Rvalue1  Rvalue2  Rvalue3  Rvalue4
# MTime
# 2020-10-17 15:51:40    46.750000 -125.309 -51.0801 -197.574  -125.49
# 2020-10-17 15:51:50    75.333333 -125.309 -51.0801 -197.574  -125.49
# 2020-10-17 15:52:00    96.000000 -125.309 -51.0801 -197.574  -125.49
# 2020-10-17 15:52:10    46.750000 -125.309 -51.0801 -197.574  -125.49
# 2020-10-17 15:52:20    75.333333 -125.309 -51.0801 -197.574  -125.49
# ...                          ...      ...      ...      ...      ...
# 2020-10-17 16:06:10          NaN      NaN      NaN      NaN      NaN
# 2020-10-17 16:06:20          NaN      NaN      NaN      NaN      NaN
# 2020-10-17 16:06:30          NaN      NaN      NaN      NaN      NaN
# 2020-10-17 16:06:40          NaN      NaN      NaN      NaN      NaN
# 2020-10-17 16:06:50          NaN      NaN      NaN      NaN      NaN
#
# [92 rows x 105 columns]

# %%
# analysing the relationship based on source and destination IP address of all the nodes
res_phy = res[['Mvalue1','Ovalue1','Rvalue1','Rvalue2','Mvalue2','Ovalue2']]
res_phy = res_phy.dropna()
res_phy
# Out:
#                         Mvalue1     Ovalue1     Rvalue1     Rvalue2  \
# MTime
# 2020-10-17 15:52:00 -125.309000 -125.309000 -125.309000  -51.080100
# 2020-10-17 15:52:10 -125.309000 -125.309000 -125.309000  -51.080100
# 2020-10-17 15:52:20 -125.309000 -125.309000 -125.309000  -51.080100
# 2020-10-17 15:52:30 -125.309000 -125.309000 -125.309000  -51.080100
# 2020-10-17 15:52:40 -125.309000 -125.309000 -125.309000  -51.080100
# ...                         ...         ...         ...         ...
# 2020-10-17 16:04:40 -377.221250 -377.221250 -369.160625 -246.652300
# 2020-10-17 16:04:50 -377.209000 -377.209000 -364.346000  -76.478200
# 2020-10-17 16:05:10 -377.206000 -377.206000 -291.033875  -78.837575
# 2020-10-17 16:05:20 -377.185000 -377.185000 -168.847000  -95.353200
# 2020-10-17 16:05:40 -375.580125 -375.580125 -168.847000  -95.353200
#
#                         Mvalue2     Ovalue2
# MTime
# 2020-10-17 15:52:00  -51.080100  -51.080100
# 2020-10-17 15:52:10  -51.080100  -51.080100
# 2020-10-17 15:52:20  -51.080100  -51.080100
# 2020-10-17 15:52:30  -51.080100  -51.080100
# 2020-10-17 15:52:40  -51.080100  -51.080100
# ...                         ...         ...
# 2020-10-17 16:04:40 -303.430000 -303.430000
# 2020-10-17 16:04:50 -303.414000 -303.414000
# 2020-10-17 16:05:10 -303.406000 -303.406000
# 2020-10-17 16:05:20 -303.396333 -303.396333
# 2020-10-17 16:05:40 -303.377000 -303.377000
#
# [77 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,7))
res_phy.plot(figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='MTime'>

# %%
# Lets discretise the values to 3 boundaries
CATS = 2

def boundary_str(start,end,cat):
    return f'{cat}: {start:+0,.2f} to {end:+0,.2f}'

def relabel(v,boundaries):
    if v>=boundaries[0][0] and v <=boundaries[0][1]:
        return boundary_str(boundaries[0][0], boundaries[0][1],cat='A')
    elif v>=boundaries[1][0] and v <=boundaries[1][1]:
        return boundary_str(boundaries[1][0], boundaries[1][1],cat='B')
#     elif v>=boundaries[2][0] and v <=boundaries[2][1]:
#         return boundary_str(boundaries[2][0], boundaries[2][1],cat='C')
    else:
        return np.nan

def get_boundaries(cats):
    prev_cat = cats[0]
    boundaries = [(prev_cat[0],prev_cat[prev_cat.shape[0]-1])]
    for index,cat in enumerate(cats):
        if index is not 0:
            boundaries.append((prev_cat[prev_cat.shape[0]-1], cat[cat.shape[0]-1]))
            prev_cat = cat
    return boundaries

new_columns= {}
for i, content in enumerate(res_phy.items()):
    (label,series) = content
    vals = np.sort(np.array([x for x in series.tolist()],dtype=float))
    boundaries = get_boundaries(cats=np.array_split(vals,CATS))
    new_columns[label] =[relabel(val,boundaries) for val in series.tolist()]
    
discrete_dt = pd.DataFrame(data=new_columns)
discrete_dt
# Out:
# <>:21: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:21: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-12-8d52da85637c>:21: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if index is not 0:
#                   Mvalue1                Ovalue1                Rvalue1  \
# 0   B: -125.31 to -125.31  A: -377.22 to -125.31  A: -377.22 to -125.31
# 1   B: -125.31 to -125.31  B: -125.31 to -125.31  B: -125.31 to -125.31
# 2   A: -377.22 to -125.31  A: -377.22 to -125.31  A: -377.22 to -125.31
# 3   A: -377.22 to -125.31  A: -377.22 to -125.31  A: -377.22 to -125.31
# 4   B: -125.31 to -125.31  B: -125.31 to -125.31  B: -125.31 to -125.31
# ..                    ...                    ...                    ...
# 72  A: -377.22 to -125.31  A: -377.22 to -125.31  A: -377.22 to -125.31
# 73  A: -377.22 to -125.31  A: -377.22 to -125.31  A: -377.22 to -125.31
# 74  A: -377.22 to -125.31  A: -377.22 to -125.31  A: -377.22 to -125.31
# 75  A: -377.22 to -125.31  A: -377.22 to -125.31  A: -377.22 to -125.31
# 76  A: -377.22 to -125.31  A: -377.22 to -125.31  A: -377.22 to -125.31
#
#                  Rvalue2               Mvalue2               Ovalue2
# 0    B: -51.08 to -51.08   B: -51.08 to -51.08   B: -51.08 to -51.08
# 1   A: -303.44 to -51.08  A: -303.44 to -51.08  A: -303.44 to -51.08
# 2    B: -51.08 to -51.08   B: -51.08 to -51.08   B: -51.08 to -51.08
# 3    B: -51.08 to -51.08   B: -51.08 to -51.08   B: -51.08 to -51.08
# 4   A: -303.44 to -51.08  A: -303.44 to -51.08  A: -303.44 to -51.08
# ..                   ...                   ...                   ...
# 72  A: -303.44 to -51.08  A: -303.44 to -51.08  A: -303.44 to -51.08
# 73  A: -303.44 to -51.08  A: -303.44 to -51.08  A: -303.44 to -51.08
# 74  A: -303.44 to -51.08  A: -303.44 to -51.08  A: -303.44 to -51.08
# 75  A: -303.44 to -51.08  A: -303.44 to -51.08  A: -303.44 to -51.08
# 76  A: -303.44 to -51.08  A: -303.44 to -51.08  A: -303.44 to -51.08
#
# [77 rows x 6 columns]

# %% [markdown]
# Bayesian Inference given a prior network model

# %%
# lets create a simple prior model in mind
from pgmpy.models import BayesianModel
from pgmpy.estimators import BayesianEstimator, MaximumLikelihoodEstimator
from IPython.core.display import display,HTML

display(HTML('<style>div.output_area pre {white-space: pre;}</style>'))

model = BayesianModel([('Rvalue1','Ovalue1'),('Rvalue1','Mvalue1'),('Rvalue2','Ovalue2'),
                       ('Rvalue2','Mvalue2')])

model.cpds=[]
model.fit(data=discrete_dt, estimator=BayesianEstimator,
         prior_type='BDeu',complete_samples_only=False)
for cpd in model.get_cpds():
    print(f'CPT of {cpd.variable}:')
    print(cpd,'\n')
# Out:
# <style>div.output_area pre {white-space: pre;}</style>
# CPT of Rvalue1:
# +--------------------------------+----------+
# | Rvalue1(A: -377.22 to -125.31) | 0.640244 |
# +--------------------------------+----------+
# | Rvalue1(B: -125.31 to -125.31) | 0.359756 |
# +--------------------------------+----------+
#
# CPT of Ovalue1:
# +--------------------------------+--------------------------------+--------------------------------+
# | Rvalue1                        | Rvalue1(A: -377.22 to -125.31) | Rvalue1(B: -125.31 to -125.31) |
# +--------------------------------+--------------------------------+--------------------------------+
# | Ovalue1(A: -377.22 to -125.31) | 0.8809523809523809             | 0.0423728813559322             |
# +--------------------------------+--------------------------------+--------------------------------+
# | Ovalue1(B: -125.31 to -125.31) | 0.11904761904761904            | 0.9576271186440678             |
# +--------------------------------+--------------------------------+--------------------------------+
#
# CPT of Mvalue1:
# +--------------------------------+--------------------------------+--------------------------------+
# | Rvalue1                        | Rvalue1(A: -377.22 to -125.31) | Rvalue1(B: -125.31 to -125.31) |
# +--------------------------------+--------------------------------+--------------------------------+
# | Mvalue1(A: -377.22 to -125.31) | 0.8047619047619048             | 0.11016949152542373            |
# +--------------------------------+--------------------------------+--------------------------------+
# | Mvalue1(B: -125.31 to -125.31) | 0.19523809523809524            | 0.8898305084745762             |
# +--------------------------------+--------------------------------+--------------------------------+
#
# CPT of Rvalue2:
# +-------------------------------+----------+
# | Rvalue2(A: -303.44 to -51.08) | 0.628049 |
# +-------------------------------+----------+
# | Rvalue2(B: -51.08 to -51.08)  | 0.371951 |
# +-------------------------------+----------+
#
# CPT of Ovalue2:
# +-------------------------------+-------------------------------+------------------------------+
# | Rvalue2                       | Rvalue2(A: -303.44 to -51.08) | Rvalue2(B: -51.08 to -51.08) |
# +-------------------------------+-------------------------------+------------------------------+
# | Ovalue2(A: -303.44 to -51.08) | 0.9757281553398058            | 0.040983606557377046         |
# +-------------------------------+-------------------------------+------------------------------+
# | Ovalue2(B: -51.08 to -51.08)  | 0.024271844660194174          | 0.9590163934426229           |
# +-------------------------------+-------------------------------+------------------------------+
#
# CPT of Mvalue2:
# +-------------------------------+-------------------------------+------------------------------+
# | Rvalue2                       | Rvalue2(A: -303.44 to -51.08) | Rvalue2(B: -51.08 to -51.08) |
# +-------------------------------+-------------------------------+------------------------------+
# | Mvalue2(A: -303.44 to -51.08) | 0.9174757281553398            | 0.1721311475409836           |
# +-------------------------------+-------------------------------+------------------------------+
# | Mvalue2(B: -51.08 to -51.08)  | 0.0825242718446602            | 0.8278688524590164           |
# +-------------------------------+-------------------------------+------------------------------+
# C:\ProgramData\Anaconda3\lib\site-packages\pgmpy\models\BayesianModel.py:8: FutureWarning: BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.
#   warnings.warn(

# %% [markdown]
# Structure Learning without any given model, using Chow Liu Tree Algorithm

# %%
est = TreeSearch(discrete_dt)
dag = est.estimate(estimator_type='chow-liu')
print(dag.edges())
# Out:
# Building tree:   0%|          | 0/15.0 [00:00<?, ?it/s]
# [('Ovalue2', 'Rvalue2'), ('Ovalue2', 'Mvalue2'), ('Rvalue2', 'Ovalue1'), ('Ovalue1', 'Rvalue1'), ('Ovalue1', 'Mvalue1')]

# %% [markdown]
# Structure Learning without any given model, using Tree-Augmented Naive Bayes (TAN) structure from Data

# %%
est = TreeSearch(discrete_dt)
dag = est.estimate(estimator_type='tan')
print(dag.edges())
# Out:
# Building tree:   0%|          | 0/15.0 [00:00<?, ?it/s]
# [('Ovalue2', 'Mvalue2'), ('Ovalue2', 'Ovalue1'), ('Ovalue1', 'Rvalue1'), ('Ovalue1', 'Mvalue1'), ('Rvalue2', 'Mvalue1'), ('Rvalue2', 'Ovalue1'), ('Rvalue2', 'Rvalue1'), ('Rvalue2', 'Mvalue2'), ('Rvalue2', 'Ovalue2')]

# %% [markdown]
# Structure Learning without any given model, using Hill Climbing Search Algo

# %%
scoring_method = K2Score(data=discrete_dt)
est = HillClimbSearch(data= discrete_dt)
est_model = est.estimate(scoring_method=scoring_method,max_iter=1e3,max_indegree=4)
print(est_model.edges())
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# [('Ovalue1', 'Mvalue1'), ('Ovalue1', 'Ovalue2'), ('Ovalue1', 'Mvalue2'), ('Rvalue1', 'Ovalue1'), ('Mvalue2', 'Mvalue1'), ('Ovalue2', 'Rvalue2'), ('Ovalue2', 'Mvalue2'), ('Ovalue2', 'Mvalue1')]

# %%
est = PC(data=discrete_dt)
est_model = est.estimate(variant='orig')
print(est_model.edges())
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# [('Rvalue1', 'Ovalue2'), ('Rvalue1', 'Rvalue2'), ('Rvalue1', 'Ovalue1'), ('Mvalue1', 'Mvalue2'), ('Ovalue2', 'Rvalue2'), ('Ovalue1', 'Mvalue1')]
# C:\ProgramData\Anaconda3\lib\site-packages\pgmpy\base\DAG.py:1187: UserWarning: PDAG has no faithful extension (= no oriented DAG with the same v-structures as PDAG). Remaining undirected PDAG edges oriented arbitrarily.
#   warn(

# %% [markdown]
# Structure Learning with Exhaustive Search

# %%
est = ExhaustiveSearch(discrete_dt)
for score,model in est.all_scores():
    print(score,model.edges())
